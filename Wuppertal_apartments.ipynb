# %%
_from bs4 import BeautifulSoup
import json
import urllib.request as urllib2
import random
from random import choice
import time

# %%
# urlquery from Achim Tack. Thank you!
# https://github.com/ATack/GoogleTrafficParser/blob/master/google_traffic_parser.py
def urlquery(url):
    # function cycles randomly through different user agents and time intervals to simulate more natural queries
    try:
        sleeptime = float(random.randint(1,6))/5
        time.sleep(sleeptime)

        agents = ['Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1309.0 Safari/537.17',
        'Mozilla/5.0 (compatible; MSIE 10.6; Windows NT 6.1; Trident/5.0; InfoPath.2; SLCC1; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 2.0.50727) 3gpp-gba UNTRUSTED/1.0',
        'Opera/12.80 (Windows NT 5.1; U; en) Presto/2.10.289 Version/12.02',
        'Mozilla/4.0 (compatible; MSIE 5.5; Windows NT)',
        'Mozilla/3.0',
        'Mozilla/5.0 (iPhone; U; CPU like Mac OS X; en) AppleWebKit/420+ (KHTML, like Gecko) Version/3.0 Mobile/1A543a Safari/419.3',
        'Mozilla/5.0 (Linux; U; Android 0.5; en-us) AppleWebKit/522+ (KHTML, like Gecko) Safari/419.3',
        'Opera/9.00 (Windows NT 5.1; U; en)']

        agent = choice(agents)
        opener = urllib2.build_opener()
        opener.addheaders = [('User-agent', agent)]

        html = opener.open(url).read()
        time.sleep(sleeptime)
        
        return html

    except Exception as e:
        print('Something went wrong with Crawling:\n%s' % e)

# %%
def immoscout24parser(url):
    
    ''' Parser holt aus Immoscout24.de Suchergebnisseiten die Immobilien '''
    
    try:
        soup = BeautifulSoup(urlquery(url), 'html.parser')
        scripts = soup.findAll('script')
        for script in scripts:
            #print script.text.strip()
            if 'IS24.resultList' in script.text.strip():
                s = script.string.split('\n')
                for line in s:
                    #print('\n\n\'%s\'' % line)
                    if line.strip().startswith('resultListModel'):
                        resultListModel = line.strip('resultListModel: ')
                        immo_json = json.loads(resultListModel[:-1])

                        searchResponseModel = immo_json[u'searchResponseModel']
                        resultlist_json = searchResponseModel[u'resultlist.resultlist']
                        
                        return resultlist_json

    except Exception as e:
        print("Fehler in immoscout24 parser: %s" % e)

# %%
immos = {}

b = 'Nordrhein-Westfalen' # Bundesland
s = 'Wuppertal' # Stadt
k = 'Wohnung' # Wohnung oder Haus
w = 'Miete' # Miete oder Kauf

page = 0
print('Suche %s / %s' % (k, w))

while True:
    page+=1
    url = 'http://www.immobilienscout24.de/Suche/S-T/P-%s/%s-%s/%s/%s?pagerReporting=true' % (page, k, w, b, s)

    # Because of some timeout or immoscout24.de errors,
    # we try until it works \o/
    resultlist_json = None
    while resultlist_json is None:
        try:
            resultlist_json = immoscout24parser(url)
            numberOfPages = int(resultlist_json[u'paging'][u'numberOfPages'])
            pageNumber = int(resultlist_json[u'paging'][u'pageNumber'])
        except:
            pass

    if page>numberOfPages:
        break

    # Get the data
    for resultlistEntry in resultlist_json['resultlistEntries'][0][u'resultlistEntry']:
        realEstate_json = resultlistEntry[u'resultlist.realEstate']
        
        realEstate = {}

        realEstate[u'Miete/Kauf'] = w
        realEstate[u'Haus/Wohnung'] = k

        realEstate['address'] = realEstate_json['address']['description']['text']
        realEstate['city'] = realEstate_json['address']['city']
        realEstate['postcode'] = realEstate_json['address']['postcode']
        realEstate['quarter'] = realEstate_json['address']['quarter']
        try:
            realEstate['lat'] = realEstate_json['address'][u'wgs84Coordinate']['latitude']
            realEstate['lon'] = realEstate_json['address'][u'wgs84Coordinate']['longitude']
        except:
            realEstate['lat'] = None
            realEstate['lon'] = None
            
        realEstate['title'] = realEstate_json['title']

        realEstate['numberOfRooms'] = realEstate_json['numberOfRooms']
        realEstate['livingSpace'] = realEstate_json['livingSpace']
        
        if k=='Wohnung':
            realEstate['balcony'] = realEstate_json['balcony']
            realEstate['builtInKitchen'] = realEstate_json['builtInKitchen']
            realEstate['garden'] = realEstate_json['garden']
            realEstate['price'] = realEstate_json['price']['value']
            realEstate['privateOffer'] = realEstate_json['privateOffer']
        elif k=='Haus':
            realEstate['isBarrierFree'] = realEstate_json['isBarrierFree']
            realEstate['cellar'] = realEstate_json['cellar']
            realEstate['plotArea'] = realEstate_json['plotArea']
            realEstate['price'] = realEstate_json['price']['value']
            realEstate['privateOffer'] = realEstate_json['privateOffer']
        
        realEstate['floorplan'] = realEstate_json['floorplan']
        realEstate['from'] = realEstate_json['companyWideCustomerId']
        realEstate['ID'] = realEstate_json[u'@id']
        realEstate['url'] = u'https://www.immobilienscout24.de/expose/%s' % realEstate['ID']

        immos[realEstate['ID']] = realEstate

    print('Scrape Page %i/%i (%i Immobilien %s %s gefunden)' % (page, numberOfPages, len(immos), k, w))
# Out:
# Suche Wohnung / Miete
# Scrape Page 1/42 (20 Immobilien Wohnung Miete gefunden)
# Scrape Page 2/42 (40 Immobilien Wohnung Miete gefunden)
# Scrape Page 3/42 (60 Immobilien Wohnung Miete gefunden)
# Scrape Page 4/42 (80 Immobilien Wohnung Miete gefunden)
# Scrape Page 5/42 (100 Immobilien Wohnung Miete gefunden)
# Scrape Page 6/42 (120 Immobilien Wohnung Miete gefunden)
# Scrape Page 7/42 (140 Immobilien Wohnung Miete gefunden)
# Scrape Page 8/42 (160 Immobilien Wohnung Miete gefunden)
# Scrape Page 9/42 (180 Immobilien Wohnung Miete gefunden)
# Scrape Page 10/42 (200 Immobilien Wohnung Miete gefunden)
# Scrape Page 11/42 (220 Immobilien Wohnung Miete gefunden)
# Scrape Page 12/42 (240 Immobilien Wohnung Miete gefunden)
# Scrape Page 13/42 (260 Immobilien Wohnung Miete gefunden)
# Scrape Page 14/42 (280 Immobilien Wohnung Miete gefunden)
# Scrape Page 15/42 (300 Immobilien Wohnung Miete gefunden)
# Scrape Page 16/42 (320 Immobilien Wohnung Miete gefunden)
# Scrape Page 17/42 (340 Immobilien Wohnung Miete gefunden)
# Scrape Page 18/42 (360 Immobilien Wohnung Miete gefunden)
# Scrape Page 19/42 (380 Immobilien Wohnung Miete gefunden)
# Scrape Page 20/42 (400 Immobilien Wohnung Miete gefunden)
# Scrape Page 21/42 (420 Immobilien Wohnung Miete gefunden)
# Scrape Page 22/42 (440 Immobilien Wohnung Miete gefunden)
# Scrape Page 23/42 (460 Immobilien Wohnung Miete gefunden)
# Scrape Page 24/42 (480 Immobilien Wohnung Miete gefunden)
# Scrape Page 25/42 (500 Immobilien Wohnung Miete gefunden)
# Scrape Page 26/42 (520 Immobilien Wohnung Miete gefunden)
# Scrape Page 27/42 (540 Immobilien Wohnung Miete gefunden)
# Scrape Page 28/42 (560 Immobilien Wohnung Miete gefunden)
# Scrape Page 29/42 (580 Immobilien Wohnung Miete gefunden)
# Scrape Page 30/42 (600 Immobilien Wohnung Miete gefunden)
# Scrape Page 31/42 (620 Immobilien Wohnung Miete gefunden)
# Scrape Page 32/42 (640 Immobilien Wohnung Miete gefunden)
# Scrape Page 33/42 (660 Immobilien Wohnung Miete gefunden)
# Scrape Page 34/42 (680 Immobilien Wohnung Miete gefunden)
# Scrape Page 35/42 (700 Immobilien Wohnung Miete gefunden)
# Scrape Page 36/42 (720 Immobilien Wohnung Miete gefunden)
# Scrape Page 37/42 (740 Immobilien Wohnung Miete gefunden)
# Scrape Page 38/42 (760 Immobilien Wohnung Miete gefunden)
# Scrape Page 39/42 (780 Immobilien Wohnung Miete gefunden)
# Scrape Page 40/42 (800 Immobilien Wohnung Miete gefunden)
# Scrape Page 41/42 (820 Immobilien Wohnung Miete gefunden)
# Scrape Page 42/42 (836 Immobilien Wohnung Miete gefunden)

# %%
print("Scraped %i Immos" % len(immos))
# Out:
# Scraped 836 Immos

# %%
from datetime import datetime
timestamp = datetime.strftime(datetime.now(), '%Y-%m-%d-%H-%M')

# %%
import pandas as pd
df = pd.DataFrame(immos).T
df.index.name = 'ID'
df.head()
# Out:
#           Haus/Wohnung         ID Miete/Kauf  \
# ID
# 107576336      Wohnung  107576336      Miete
# 110256105      Wohnung  110256105      Miete
# 110293125      Wohnung  110293125      Miete
# 110293111      Wohnung  110293111      Miete
# 110613634      Wohnung  110613634      Miete
#
#                                                      address balcony  \
# ID
# 107576336      Bramdelle 35, Langerfeld-Beyenburg, Wuppertal   false
# 110256105  Hamburger Straße 24, Uellendahl-Katernberg, Wu...   false
# 110293125  Jesinghauser Str. 83, Langerfeld-Beyenburg, Wu...   false
# 110293111  Jesinghauser Str. 79, Langerfeld-Beyenburg, Wu...   false
# 110613634  Jesinghauser Str. 79, Langerfeld-Beyenburg, Wu...   false
#
#           builtInKitchen       city floorplan         from garden      lat  \
# ID
# 107576336          false  Wuppertal     false   001.947582  false  51.2881
# 110256105          false  Wuppertal      true   001.947582   true  51.2697
# 110293125          false  Wuppertal     false  001.1924949  false  51.2826
# 110293111          false  Wuppertal     false  001.1924949  false  51.2825
# 110613634          false  Wuppertal     false  001.1924949  false  51.2825
#
#           livingSpace      lon numberOfRooms postcode   price privateOffer  \
# ID
# 107576336       44.62   7.2417             2    42279  334.65        false
# 110256105        79.8  7.14778             2    42109   598.5        false
# 110293125          55   7.2524             3    42389     323        false
# 110293111          55  7.25189             3    42389     324        false
# 110613634          56  7.25189             3    42389     330        false
#
#                          quarter  \
# ID
# 107576336   Langerfeld-Beyenburg
# 110256105  Uellendahl-Katernberg
# 110293125   Langerfeld-Beyenburg
# 110293111   Langerfeld-Beyenburg
# 110613634   Langerfeld-Beyenburg
#
#                                                        title  \
# ID
# 107576336  ERSTBEZUG nach Renovierung**helle 2-Zimmerwohn...
# 110256105  Großzügige 2-Zimmer DG-Wohnung**Schöner denkma...
# 110293125      Ihr neues Wohlfühlheim! **mit Tageslichtbad**
# 110293111  Einziehen! Wohlfühlen! Fertig! **mit Tageslich...
# 110613634  Einziehen! Wohlfühlem! Fertig! ** mit Tageslic...
#
#                                                          url
# ID
# 107576336  https://www.immobilienscout24.de/expose/107576336
# 110256105  https://www.immobilienscout24.de/expose/110256105
# 110293125  https://www.immobilienscout24.de/expose/110293125
# 110293111  https://www.immobilienscout24.de/expose/110293111
# 110613634  https://www.immobilienscout24.de/expose/110613634

# %%
f = open('%s-%s-%s.csv' % (timestamp, k, w), 'w')
f.write('# %s %s from immoscout24.de on %s\n' % (k,w,timestamp))
df[(df['Haus/Wohnung']==k) & (df['Miete/Kauf']==w)].to_csv(f, encoding='utf-8')
f.close()

# %%
df.to_excel('%s-%s-%s.xlsx' % (timestamp, k, w))

# %%
df.head()
# Out:
#           Haus/Wohnung         ID Miete/Kauf  \
# ID
# 107576336      Wohnung  107576336      Miete
# 110256105      Wohnung  110256105      Miete
# 110293125      Wohnung  110293125      Miete
# 110293111      Wohnung  110293111      Miete
# 110613634      Wohnung  110613634      Miete
#
#                                                      address balcony  \
# ID
# 107576336      Bramdelle 35, Langerfeld-Beyenburg, Wuppertal   false
# 110256105  Hamburger Straße 24, Uellendahl-Katernberg, Wu...   false
# 110293125  Jesinghauser Str. 83, Langerfeld-Beyenburg, Wu...   false
# 110293111  Jesinghauser Str. 79, Langerfeld-Beyenburg, Wu...   false
# 110613634  Jesinghauser Str. 79, Langerfeld-Beyenburg, Wu...   false
#
#           builtInKitchen       city floorplan         from garden      lat  \
# ID
# 107576336          false  Wuppertal     false   001.947582  false  51.2881
# 110256105          false  Wuppertal      true   001.947582   true  51.2697
# 110293125          false  Wuppertal     false  001.1924949  false  51.2826
# 110293111          false  Wuppertal     false  001.1924949  false  51.2825
# 110613634          false  Wuppertal     false  001.1924949  false  51.2825
#
#           livingSpace      lon numberOfRooms postcode   price privateOffer  \
# ID
# 107576336       44.62   7.2417             2    42279  334.65        false
# 110256105        79.8  7.14778             2    42109   598.5        false
# 110293125          55   7.2524             3    42389     323        false
# 110293111          55  7.25189             3    42389     324        false
# 110613634          56  7.25189             3    42389     330        false
#
#                          quarter  \
# ID
# 107576336   Langerfeld-Beyenburg
# 110256105  Uellendahl-Katernberg
# 110293125   Langerfeld-Beyenburg
# 110293111   Langerfeld-Beyenburg
# 110613634   Langerfeld-Beyenburg
#
#                                                        title  \
# ID
# 107576336  ERSTBEZUG nach Renovierung**helle 2-Zimmerwohn...
# 110256105  Großzügige 2-Zimmer DG-Wohnung**Schöner denkma...
# 110293125      Ihr neues Wohlfühlheim! **mit Tageslichtbad**
# 110293111  Einziehen! Wohlfühlen! Fertig! **mit Tageslich...
# 110613634  Einziehen! Wohlfühlem! Fertig! ** mit Tageslic...
#
#                                                          url
# ID
# 107576336  https://www.immobilienscout24.de/expose/107576336
# 110256105  https://www.immobilienscout24.de/expose/110256105
# 110293125  https://www.immobilienscout24.de/expose/110293125
# 110293111  https://www.immobilienscout24.de/expose/110293111
# 110613634  https://www.immobilienscout24.de/expose/110613634

# %%
#Rename some columns
df.rename(columns={'lat':'Latitude',
                       'lon':'Longitude',
                       'numberOfRooms':'Rooms',
                       'postcode':'PostalCode',
                       'quarter':'Neighborhood',
                       'livingSpace':'Space',
                       'builtInKitchen':'Kitchen',
                       'garden':'Garden',
                       'price':'Price'        
                      }, 
                 inplace=True)
df.tail()
# Out:
#          Haus/Wohnung        ID Miete/Kauf  \
# ID
# 51813825      Wohnung  51813825      Miete
# 50764285      Wohnung  50764285      Miete
# 40457817      Wohnung  40457817      Miete
# 35761307      Wohnung  35761307      Miete
# 30826857      Wohnung  30826857      Miete
#
#                                                     address balcony Kitchen  \
# ID
# 51813825          Grünewalder Berg 20, Elberfeld, Wuppertal   false   false
# 50764285                Sonnenstr. 5, Oberbarmen, Wuppertal    true   false
# 40457817  Hahnerberger Straße 109+111, Cronenberg, Wuppe...   false    true
# 35761307                Rolandstr. 10, Elberfeld, Wuppertal   false   false
# 30826857                Hammer Weg 8, Cronenberg, Wuppertal   false    true
#
#                city floorplan         from Garden Latitude  Space Longitude  \
# ID
# 51813825  Wuppertal     false  001.2649978  false  51.2572     73   7.13775
# 50764285  Wuppertal     false   001.596601   true   51.277     70   7.22659
# 40457817  Wuppertal      true  001.1071159   true  51.2242  22.42   7.15206
# 35761307  Wuppertal     false   001.553128  false  51.2603     72   7.14117
# 30826857  Wuppertal     false   001.328073  false  51.2165  24.88   7.15112
#
#          Rooms PostalCode   Price privateOffer Neighborhood  \
# ID
# 51813825     3      42105     500         true    Elberfeld
# 50764285     2      42277     455         true   Oberbarmen
# 40457817     1      42349  120.17        false   Cronenberg
# 35761307     2      42105     465         true    Elberfeld
# 30826857     1      42349  145.77         true   Cronenberg
#
#                                                       title  \
# ID
# 51813825  Schöne, helle Dreizimmerwohnung im Luisenviert...
# 50764285  Wohnen im Grünen und doch citynah in Wuppertal...
# 40457817  Studenten-Appartements in Uni-Nähe (Muster-App...
# 35761307      hmmm-WHIRLPOOL-2 Zimmer G-WC-Parkett-Citylage
# 30826857  Studenten-Appartement in Uni Nähe, WBS erforde...
#
#                                                        url
# ID
# 51813825  https://www.immobilienscout24.de/expose/51813825
# 50764285  https://www.immobilienscout24.de/expose/50764285
# 40457817  https://www.immobilienscout24.de/expose/40457817
# 35761307  https://www.immobilienscout24.de/expose/35761307
# 30826857  https://www.immobilienscout24.de/expose/30826857

# %%
#The file contains some columns useless, so we drop them
df_apartment = df.drop(['Haus/Wohnung', 'Garden', 'ID', 'balcony','floorplan','from','privateOffer','title','city','Miete/Kauf','PostalCode','address'], axis=1)
df_apartment.head()
# Out:
#           Kitchen Latitude  Space Longitude Rooms   Price  \
# ID
# 107576336   false  51.2881  44.62    7.2417     2  334.65
# 110256105   false  51.2697   79.8   7.14778     2   598.5
# 110293125   false  51.2826     55    7.2524     3     323
# 110293111   false  51.2825     55   7.25189     3     324
# 110613634   false  51.2825     56   7.25189     3     330
#
#                     Neighborhood  \
# ID
# 107576336   Langerfeld-Beyenburg
# 110256105  Uellendahl-Katernberg
# 110293125   Langerfeld-Beyenburg
# 110293111   Langerfeld-Beyenburg
# 110613634   Langerfeld-Beyenburg
#
#                                                          url
# ID
# 107576336  https://www.immobilienscout24.de/expose/107576336
# 110256105  https://www.immobilienscout24.de/expose/110256105
# 110293125  https://www.immobilienscout24.de/expose/110293125
# 110293111  https://www.immobilienscout24.de/expose/110293111
# 110613634  https://www.immobilienscout24.de/expose/110613634

# %%
#I'm reorganizing the columns in order to be easier to understand
df_apartment = df_apartment[['Neighborhood', 'Latitude','Longitude','Price','Rooms','Space','Kitchen','url']]
df_apartment.head()
# Out:
#                     Neighborhood Latitude Longitude   Price Rooms  Space  \
# ID
# 107576336   Langerfeld-Beyenburg  51.2881    7.2417  334.65     2  44.62
# 110256105  Uellendahl-Katernberg  51.2697   7.14778   598.5     2   79.8
# 110293125   Langerfeld-Beyenburg  51.2826    7.2524     323     3     55
# 110293111   Langerfeld-Beyenburg  51.2825   7.25189     324     3     55
# 110613634   Langerfeld-Beyenburg  51.2825   7.25189     330     3     56
#
#           Kitchen                                                url
# ID
# 107576336   false  https://www.immobilienscout24.de/expose/107576336
# 110256105   false  https://www.immobilienscout24.de/expose/110256105
# 110293125   false  https://www.immobilienscout24.de/expose/110293125
# 110293111   false  https://www.immobilienscout24.de/expose/110293111
# 110613634   false  https://www.immobilienscout24.de/expose/110613634

# %%
#Now, we have to drop the NaN rows
df_apartment = df_apartment.dropna()
df_apartment.head()
# Out:
#                     Neighborhood Latitude Longitude   Price Rooms  Space  \
# ID
# 107576336   Langerfeld-Beyenburg  51.2881    7.2417  334.65     2  44.62
# 110256105  Uellendahl-Katernberg  51.2697   7.14778   598.5     2   79.8
# 110293125   Langerfeld-Beyenburg  51.2826    7.2524     323     3     55
# 110293111   Langerfeld-Beyenburg  51.2825   7.25189     324     3     55
# 110613634   Langerfeld-Beyenburg  51.2825   7.25189     330     3     56
#
#           Kitchen                                                url
# ID
# 107576336   false  https://www.immobilienscout24.de/expose/107576336
# 110256105   false  https://www.immobilienscout24.de/expose/110256105
# 110293125   false  https://www.immobilienscout24.de/expose/110293125
# 110293111   false  https://www.immobilienscout24.de/expose/110293111
# 110613634   false  https://www.immobilienscout24.de/expose/110613634

# %%
#To solve my problem, I'm looking for flats that are under 500€ and which have kitchen
df_apartment = df_apartment[(df_apartment.Price < 500) & (df_apartment.Kitchen == 'true')]
df_apartment.head()
# Out:
#              Neighborhood Latitude Longitude Price Rooms Space Kitchen  \
# ID
# 110429907          Barmen  51.2632   7.19012   331     2    48    true
# 110986178       Vohwinkel  51.2328   7.08696   430     2    48    true
# 77406973        Elberfeld  51.2636   7.14511   280     1    30    true
# 109896859        Ronsdorf  51.2277   7.20453   250     1    25    true
# 111024017  Elberfeld West  51.2497   7.12178   470     2    57    true
#
#                                                          url
# ID
# 110429907  https://www.immobilienscout24.de/expose/110429907
# 110986178  https://www.immobilienscout24.de/expose/110986178
# 77406973    https://www.immobilienscout24.de/expose/77406973
# 109896859  https://www.immobilienscout24.de/expose/109896859
# 111024017  https://www.immobilienscout24.de/expose/111024017

# %%
#In order to save my dataframe, I've to connect the notebook to my drive and enter my token
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
#Now, I can save my df to my drive
df_apartment.to_csv('scraping_apartments.csv')
# !cp scraping_apartments.csv drive/My\ Drive/
